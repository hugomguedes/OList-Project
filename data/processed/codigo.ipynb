# %%
print("Renan")
# Out:
# Renan

# %%
import pandas as pd  # Importa a biblioteca pandas para trabalhar com os arquivos CSV
from pathlib import Path  # Importa Path para localizar arquivos na pasta
from IPython.display import display  # Importa display para mostrar as tabelas no notebook

raw_folder = Path('../data/raw')  # Define a pasta onde estão os arquivos CSV

for file_path in raw_folder.glob('*.csv'):
    print(f'Arquivo: {file_path.name}')  # Mostra o nome do arquivo
# Out:
# Arquivo: olist_customers_dataset.csv
# Arquivo: olist_geolocation_dataset.csv
# Arquivo: olist_orders_dataset.csv
# Arquivo: olist_order_items_dataset.csv
# Arquivo: olist_order_payments_dataset.csv
# Arquivo: olist_order_reviews_dataset.csv
# Arquivo: olist_products_dataset.csv
# Arquivo: olist_sellers_dataset.csv
# Arquivo: product_category_name_translation.csv
